# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.insert(0, '../source')

# %%
rm -rf /Users/agstubbl/Desktop/stokes-shelf/results/stream_Idea0/

# %%
# !mpirun -np 4 python3 ../source/main.py setup_stream
# Out:
#   0 SNES Function norm 8.203846458178e+06
#   1 SNES Function norm 2.268684835347e-06
#   0 SNES Function norm 8.203844344061e+06
#   1 SNES Function norm 2.416403646341e-06
#   0 SNES Function norm 8.203842230598e+06
#   1 SNES Function norm 2.417950063309e-06
#   0 SNES Function norm 8.203840117524e+06
#   1 SNES Function norm 2.415052430511e-06
#   0 SNES Function norm 8.203838004703e+06
#   1 SNES Function norm 2.415665260924e-06
#   0 SNES Function norm 8.203835892059e+06
#   1 SNES Function norm 2.418309707508e-06
#   0 SNES Function norm 8.203833779550e+06
#   1 SNES Function norm 2.416790216174e-06
#   0 SNES Function norm 8.203831667150e+06
#   1 SNES Function norm 2.417936079580e-06
#   0 SNES Function norm 8.203829554843e+06
#   1 SNES Function norm 2.419479410219e-06
# Time step 3650 of 3650 completed (100.0%)
